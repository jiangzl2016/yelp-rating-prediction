# %% [markdown]
# ## Yelp Challenge

# %% [markdown]
# Dataset Documentation: <br>
# https://www.yelp.com/dataset/documentation/main

# %%
import pandas as pd
import numpy as np
from cmfrec import CMF
import pycmf

from surprise import SVD
from surprise import accuracy
from surprise import Reader
from surprise import KNNBasic

import matplotlib.pyplot as plt
import tarfile
import json
from tqdm import tqdm

# %%
zf = tarfile.open('yelp_dataset.tar') 
#df = pd.read_csv(zf.open('intfile.csv'))
for name in zf.list():
    print (name)
# Out:
# ?rw-r--r-- daniellg/users  138279749 2018-11-15 11:22:39 business.json
# ?rw-r--r-- daniellg/users  408807658 2018-11-15 11:25:00 checkin.json
# ?rw-r--r-- daniellg/users 5347475638 2018-11-15 11:35:37 review.json
# ?rw-r--r-- daniellg/users  244535478 2018-11-15 11:26:18 tip.json
# ?rw-r--r-- daniellg/users 2485747393 2018-11-15 11:24:48 user.json
# ?rw-r--r-- daniellg/users   25661152 2019-01-11 19:06:09 photo.json
# ?rw-r--r-- daniellg/users     101186 2019-01-14 11:31:35 Dataset_Challenge_Dataset_Agreement.pdf
# ?rw-r--r-- daniellg/users     111822 2019-01-14 11:35:09 Yelp_Dataset_Challenge_Round_13.pdf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9e2a3a38cd06> in <module>
#       1 zf = tarfile.open('yelp_dataset.tar')
#       2 #df = pd.read_csv(zf.open('intfile.csv'))
# ----> 3 for name in zf.list():
#       4     print (name)
#
# TypeError: 'NoneType' object is not iterable

# %%
## Feel free to extract more files here
zf.extract("review.json")
zf.extract("business.json")
zf.extract("user.json")

# %%
# load business.json
# 192609 unique businesses?
line_count = len(open("./yelp_dataset/business.json").readlines())
business_ids, cities, states, latitudes, longitudes, stars, review_counts, attributes, categories = [], [], [], [], [], [], [], [], []
with open("./yelp_dataset/business.json") as f:
    for line in tqdm(f, total=line_count):
        blob = json.loads(line)
        business_ids += [blob["business_id"]]
        cities += [blob["city"]]
        states += [blob["state"]]
        latitudes += [blob["latitude"]]
        longitudes += [blob["longitude"]]
        stars += [blob["stars"]]
        review_counts += [blob["review_count"]]
        attributes += [blob["attributes"]]
        categories += [blob["categories"]]
        
businesses = pd.DataFrame(
    {"business_id": business_ids, "city": cities, "state": states, "latitude": latitudes, "longitude": longitudes, "stars": stars, "review_counts": review_counts, "attributes": attributes, "categories":categories }
)
# Out:
# 100%|██████████| 192609/192609 [00:02<00:00, 74126.15it/s]

# %%
# load user.json
# 1637138 unique users?
line_count = len(open("./yelp_dataset/user.json").readlines())
users, review_counts, elites, average_stars, friends = [], [], [], [], []
with open("./yelp_dataset/user.json") as f:
    for line in tqdm(f, total=line_count):
        blob = json.loads(line)
        users += [blob["user_id"]]
        review_counts += [blob["review_count"]]
        elites += [blob["elite"]]
        average_stars += [blob["average_stars"]]
        friends += [blob["friends"]]
        
users = pd.DataFrame(
    {"user_id": users, "review_count": review_counts,"elite": elites, "average_stars": average_stars, "friends": friends}
)
# Out:
# 100%|██████████| 1637138/1637138 [00:20<00:00, 81636.78it/s]

# %%
# load review.json
# 6685900 unique reviews?
line_count = len(open("./yelp_dataset/review.json").readlines())
user_ids, business_ids, stars, dates, texts = [], [], [], [], []
with open("./yelp_dataset/review.json") as f:
    for line in tqdm(f, total=line_count):
        blob = json.loads(line)
        user_ids += [blob["user_id"]]
        business_ids += [blob["business_id"]]
        stars += [blob["stars"]]
        dates += [blob["date"]]
        texts += [blob["text"]]
reviews = pd.DataFrame(
    {"user_id": user_ids, "business_id": business_ids, "rating": stars, "date": dates, "text": texts}
)
user_counts = reviews["user_id"].value_counts()
active_users = user_counts.loc[user_counts >= 5].index.tolist()
reviews = reviews.loc[reviews.user_id.isin(active_users)]
# Out:
# 100%|██████████| 6685900/6685900 [00:58<00:00, 114841.67it/s]

# %%
ratings_holdout = pd.read_csv('data/ratings_sample_holdout.csv')

# %%
ratings_train = pd.read_csv('data/ratings_sample_train.csv')

# %%
ratings_val = pd.read_csv('data/ratings_sample_cv.csv')

# %%
def process(df):
    df = df.drop(df.columns[0], axis =1)
    df['date']  = pd.to_datetime(df['date'])
    df['week_day'] = df['date'].dt.weekday
    df['month'] = df['date'].dt.month
    df['hour'] = df['date'].dt.hour
    df = df.merge(users, on = 'user_id')
    df = df.merge(businesses, on = 'business_id')
    return df

# %%
# states with less than 10 restaurants are already filtered out
ratings_train = process(ratings_train.copy())

# %%
ratings_holdout = process(ratings_holdout.copy())

# %%
ratings_val = process(ratings_val.copy())

# %%
print('There are {0} rows, {1} columns in training set.'.format(ratings_train.shape[0], ratings_train.shape[1]))
print('There are {0} rows, {1} columns in holdout set.'.format(ratings_holdout.shape[0], ratings_holdout.shape[1]))
print('There are {0} rows, {1} columns in validation set.'.format(ratings_val.shape[0], ratings_val.shape[1]))
# Out:
# There are 406042 rows, 20 columns in training set.
# There are 28612 rows, 20 columns in holdout set.
# There are 28615 rows, 20 columns in validation set.

# %%
ratings_train.shape
# Out:
# (406042, 20)

# %% [markdown]
# ## Baseline: SVD as Matrix Factorization
#
# As a CF algorithm. A matrix factorization technique that reduces the number of features of a data set by reducing space dimensions from N to K where K < N. Thus, in our context, we are finding 2 matrices whose product is the original matrix.

# %%
algo = SVD()

# %%
trainset = ratings_train.iloc[:,0:3]
trainset.columns = ['userID', 'itemID','rating']
trainset
# Out:
#                         userID                  itemID  rating
# 0       n6-Gk65cPZL6Uz8qRm3NYw  WTqjgwHlXbSFevF32_DJVw     5.0
# 1       bLPmbJ0x70HSHfD-2n_smw  WTqjgwHlXbSFevF32_DJVw     1.0
# 2       n6-Gk65cPZL6Uz8qRm3NYw  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 3       wJgtf18VKKZq9A6ZQUybQw  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 4       jqyS91iI63nyztPAvRk1AQ  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 5       ktm2YMsb65tRnePcYpVlqg  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 6       CHUMBPZdstb0OMc26jlldg  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 7       CHUMBPZdstb0OMc26jlldg  30Q5xBagQHmkwp8Q9I1FCg     3.0
# 8       iOR5mdeMaR36VbA76IGbMQ  30Q5xBagQHmkwp8Q9I1FCg     2.0
# 9       X7NHc1i4LgqCPiltnuvR1g  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 10      oXDS2gQ-2kbjOTEHQ5nb1Q  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 11      s7W-PFXAhqBxTw0wqJ1JEA  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 12      JHa6QhwsnQ3tBfoHwz9pJg  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 13      sNlbpvPA5Mg7MMZXphRJAA  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 14      t7gM9zerhBzufAsrgx8GzA  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 15      yGQ79bkbIUlkF6xKCaAf3A  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 16      IyeMSj7mju67Q7zs4QSxTg  30Q5xBagQHmkwp8Q9I1FCg     3.0
# 17      RPg7vzYRsAJy-GBp8CrSsA  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 18      ytlj-nxVL8pX5gCEdUhVjw  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 19      n6-Gk65cPZL6Uz8qRm3NYw  UtWngqS-WloIY_A53W5K-Q     5.0
# 20      l-B4axUNxQ9FVVxeQm8t2A  UtWngqS-WloIY_A53W5K-Q     2.0
# 21      mjhC0hdu1mt4SMbdQBqCHA  UtWngqS-WloIY_A53W5K-Q     5.0
# 22      rkmTGP3FR3_uUb-urnD9qA  UtWngqS-WloIY_A53W5K-Q     4.0
# 23      XM3xtNqthJj2736FDD-gSw  UtWngqS-WloIY_A53W5K-Q     1.0
# 24      qW12oOxahfbm6cbrCv72Iw  UtWngqS-WloIY_A53W5K-Q     1.0
# 25      RtrYx7l2vPJ-8tk5M_a4Ng  UtWngqS-WloIY_A53W5K-Q     5.0
# 26      PECPA5Aj1zEQ30ejMG31Iw  UtWngqS-WloIY_A53W5K-Q     1.0
# 27      1URgpcG2uv0kH2oP_RSGbA  UtWngqS-WloIY_A53W5K-Q     5.0
# 28      m9PQbQBnc3KyusOMrmE7xw  UtWngqS-WloIY_A53W5K-Q     4.0
# 29      PiUh_zFkm91FXGxjKaGzNA  UtWngqS-WloIY_A53W5K-Q     1.0
# ...                        ...                     ...     ...
# 406012  bd-fJCIqjGHf_0Sr3cpeIw  LivM8th5aKOCym2rBOypaQ     5.0
# 406013  bd-fJCIqjGHf_0Sr3cpeIw  zcRffpb9mP25Law5ccbsKQ     1.0
# 406014  DIN8hew5VSuVBvzu2E2HxQ  Fd5Q8GrB-jlAIPM8AmL07w     5.0
# 406015  UzeNGTY0P-7BSl10seC41Q  v2GJWvZqEAjUc22hZUYzYw     2.0
# 406016  u18VHGQINV4g0EEBun3VdQ  _ULxHE2fF-9C4cCRBdFbiw     1.0
# 406017  BtJ_JaUGhEVMkhKk3OgPeA  MvVCSyFIpmKKV8URk0HWIQ     1.0
# 406018  HjXyQ3AkIBi0l6AkPFL8eQ  HcEJ2YiSLX_mT3RE0hvKWQ     1.0
# 406019  SsxFxIn4CQXlvsg1L5JYzA  k9nfd3oUEGjd8G1FMfLbMQ     1.0
# 406020  SsxFxIn4CQXlvsg1L5JYzA  k9nfd3oUEGjd8G1FMfLbMQ     1.0
# 406021  ZSa87jzrbvNx2iKLXxDcgA  RvrR0l5QGUK5qxcHZUSrFA     1.0
# 406022  ZSa87jzrbvNx2iKLXxDcgA  AE3Qz_POf13piq2Z-RA5Kg     1.0
# 406023  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406024  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406025  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406026  j9hSpmKjnIhSQpn8Cgx6WQ  w4rh3YzQ4DkOIE9MNs8_jA     5.0
# 406027  Yg5WB_IxkUDXGG3__KBmIw  BOMFEp6rhfREWwia0AhVdg     5.0
# 406028  vcjgxb2wrY77KY_LUIBGPQ  499ugPqwBhr-EQYnCuFC0A     5.0
# 406029  vcjgxb2wrY77KY_LUIBGPQ  499ugPqwBhr-EQYnCuFC0A     5.0
# 406030  vcjgxb2wrY77KY_LUIBGPQ  y3yzAYE9pFyYtGgyKsyuLw     1.0
# 406031  rBGStJwT8F31ZKfxR-3LDg  KHMowVxKO348SVGzfMh88A     5.0
# 406032  A6QhMRq4IoSi8jwztMaPZw  44diypduswYIqxBSrNr0lA     1.0
# 406033  ZIGAOAheQcxegpQiQLlvKA  ru7uYlgpg7vwRDFVQlpNaw     4.0
# 406034  Al1sBOu0clEMRmIrURVKYQ  -LdlgJrCqdgmf2Zq005cIg     5.0
# 406035  Al1sBOu0clEMRmIrURVKYQ  qY4uRygFDKieLa8n4C6WJg     5.0
# 406036  3pkmfj8YNe4I-WMAjPWX6w  ny79ZOnR9yLTN85Vg2BJVg     1.0
# 406037  HTHkos0ZMecUwNVChYtLfQ  tsHIGsL9LsXDEjHGhpIbLg     5.0
# 406038  fj4Civ5Ec2KD3TcbxX2iTQ  Lh6EHPV59bE_j1Hi65OXNw     5.0
# 406039  M1lN8ENVHvFexfYA-0-f5g  1lWgMvsY8QvrFlnXong-pg     5.0
# 406040  M1lN8ENVHvFexfYA-0-f5g  FUcreFa1JIkNCbJH8zYRbw     1.0
# 406041  M1lN8ENVHvFexfYA-0-f5g  FUcreFa1JIkNCbJH8zYRbw     1.0
#
# [406042 rows x 3 columns]

# %%
testset = ratings_holdout.iloc[:, 0:3]
testset.columns = ['userID', 'itemID','rating']
testset
# Out:
#                        userID                  itemID  rating
# 0      n6-Gk65cPZL6Uz8qRm3NYw  hk5wpV-_pi5jmDDVPeG8DA     5.0
# 1      FIk4lQQu1eTe2EpzQ4xhBA  jLxeBgWhLRbII2ACkgH1Sg     4.0
# 2      9cOyDUT20H7iTxU9CU8I6Q  jLxeBgWhLRbII2ACkgH1Sg     5.0
# 3      _N7Ndn29bpll_961oPeEfw  O-b5osM0NO4f31dp6_DatQ     3.0
# 4      453V8MlGr8y61PpsDAFjKQ  O-b5osM0NO4f31dp6_DatQ     5.0
# 5      oYYxqbRWb92oBajOQP8NlA  O-b5osM0NO4f31dp6_DatQ     5.0
# 6      GMkjaAJ3puIf0zn1E1TVXQ  O-b5osM0NO4f31dp6_DatQ     5.0
# 7      C_hUvw2z0R-Rv0yZb6QCZA  O19VReN1I2TBrJsbXUAIJg     5.0
# 8      Y0UHmlB06TZ1OQuQoQ4dxw  O19VReN1I2TBrJsbXUAIJg     5.0
# 9      bCpimZ6jX8SRX7woLu09eQ  O19VReN1I2TBrJsbXUAIJg     5.0
# 10     DbccYu3OppWKl21OanZnTg  dTqKpbaiUgEd4rPSzKuWqQ     5.0
# 11     6MsHD7EbrjT6COvOeoBeUQ  dTqKpbaiUgEd4rPSzKuWqQ     4.0
# 12     aXhMt_8ZDmfpr2QZ3zlmog  6Hnf8Vk2BOuyDf11PZdvSw     2.0
# 13     6KdJciNw5ja42-5XSFb3Fw  -fhq3ydpr22WWHCMwaw8oQ     5.0
# 14     x37OyP--VEFE5p-xreplYA  H8YxhXKpZ_2E0axGRrsp2w     4.0
# 15     62GNFh5FySkA3MbrQmnqvg  MVHaUexefp1XbqDw0_YYqQ     4.0
# 16     CcRE8FxBOoXUCjGegw3iig  MVHaUexefp1XbqDw0_YYqQ     5.0
# 17     pt-FZuw9oMLJXr_HKQuw0g  MVHaUexefp1XbqDw0_YYqQ     5.0
# 18     Db0u8Kn3s3jkBVqUoG-1fQ  MVHaUexefp1XbqDw0_YYqQ     5.0
# 19     iL3YaRr3jgy8RjwWwZ6SJg  3ItnRCpQFlOU0_oJKoS0Jw     2.0
# 20     W2WICriV5Zf03S4ETzEsiQ  R_ZlcX46pPdjhjmfd043LA     5.0
# 21     9hUe32CLBmdi-H_V9wkkyQ  R_ZlcX46pPdjhjmfd043LA     3.0
# 22     IpEBJtEXwFeyg_53SMoR1Q  R_ZlcX46pPdjhjmfd043LA     4.0
# 23     5_UI7CVCwHuZM4NCis6YBA  R_ZlcX46pPdjhjmfd043LA     5.0
# 24     0lHJeo5uobYx7K59YasP_w  R_ZlcX46pPdjhjmfd043LA     5.0
# 25     2k8OVAPxlXHsA5X6EIoQpQ  xUNBb5qkJ6Vo60M5RPPA7w     5.0
# 26     i8O9HI9mZZI1MRK2LrJmFA  q0iqz7ZQmOi7TqqciKVJYw     5.0
# 27     tKES7VN58viXkgLxTyyhNg  q0iqz7ZQmOi7TqqciKVJYw     5.0
# 28     CBYlr6bksWM1WA_pTumeeg  3x45Q9c5G6VBicedNKrXxQ     5.0
# 29     98S0b7UD-CGBGX0f4LPNvQ  3x45Q9c5G6VBicedNKrXxQ     1.0
# ...                       ...                     ...     ...
# 28582  KpksAPHviTqWOQbsh73V-Q  daDHbd1gtDvjxerVjn8A7g     5.0
# 28583  DIN8hew5VSuVBvzu2E2HxQ  jlA6zUZiSOKhnT2JIHziEw     5.0
# 28584  m-9E-Z8Vl5x0zc5Ko3YugQ  9-eMqJiY9YW_IVTIandMHw     1.0
# 28585  u18VHGQINV4g0EEBun3VdQ  ON6XftIGX8YqAHL_pPBHFQ     1.0
# 28586  b6dSUXm1yELAzvWaGTojYQ  h9pEt23IAyjBtUaYA9v46A     5.0
# 28587  -PBztFmQpvlpprGvGlselg  i3tQsfpdKoXttqp4CFLA-Q     5.0
# 28588  QWy2JhifIQXAHy5Kxp0I9A  X54KJLDkLE1Raaa5hojdnw     4.0
# 28589  32lk28FocvHdZ8kgMzaR3Q  JBrBsKpw0bbXK5nlrXVOYQ     5.0
# 28590  TGO7cuSM6T8gkgiXu-6Ghg  v6YvYMjxMMS3L-UQe5WAiQ     4.0
# 28591  koniFYe7rXmtma9JLgR8vg  sfa7IPru2FRBaf7LX-lWqA     5.0
# 28592  SsxFxIn4CQXlvsg1L5JYzA  k9nfd3oUEGjd8G1FMfLbMQ     1.0
# 28593  ZSa87jzrbvNx2iKLXxDcgA  QBRi0JFPZ1SQT0O14hg9xA     1.0
# 28594  AmcTLG6M8UroPXw1MsH5Dw  dd912h3cntI-oG6iYWuxSQ     4.0
# 28595  qKXYsVrQkbi4HBaprFgzZw  8SPVk_NrPmqSW0dYd6BlEA     5.0
# 28596  1h20Sz9J-XIio5Wv4VMstA  eEeKRTNSHfbpG6E9VDnJDw     2.0
# 28597  Cbh3HsgbqgWk1IEdNWX8Mg  W9y-Bl9030-rmfxSTmUD_g     5.0
# 28598  vF0f7dAZg1idS4iyafwqXw  8nv2zN73EqHMI9eHeWmX7g     4.0
# 28599  Yg5WB_IxkUDXGG3__KBmIw  SHUxrf78U3aRO5Lgd_82vw     5.0
# 28600  A6QhMRq4IoSi8jwztMaPZw  EivNc0ob6BSfg99DLXZaSw     5.0
# 28601  K_j5tAtpbYbZkqIpATgJmA  jBxrK5sbvH_gbMwJO63loA     4.0
# 28602  rcfAxqY0P_4Ub89_BmPObQ  bf4fA13B6MhGows7Sq8Hgg     3.0
# 28603  Al1sBOu0clEMRmIrURVKYQ  FYWN1wneV18bWNgQjJ2GNg     1.0
# 28604  3pkmfj8YNe4I-WMAjPWX6w  BwWbwhIWfc9A0fPShp-WmA     5.0
# 28605  VazHiRETFlZMpYthkgwdmA  nD0HPNxlMooPovEI8M_FAQ     1.0
# 28606  jIklSu7OsIQNde_7Sv7Jcw  1_fKz8LMENf_ytqRKET1Cw     5.0
# 28607  fj4Civ5Ec2KD3TcbxX2iTQ  YAdyu9ovEiOZXBWkD0H8-Q     4.0
# 28608  Yeh6xRX8CLHFZFH1q922Ig  YUE5S4ReiM4dq9qkKbDMwg     5.0
# 28609  0Y6MiTQqUyoee-6G0vYuCw  hxe8xidZ04BfdqQ-oUADiQ     5.0
# 28610  M1lN8ENVHvFexfYA-0-f5g  FUcreFa1JIkNCbJH8zYRbw     1.0
# 28611  Zm4-RVaQ_8SQ9vGdnAXPAA  uvyTWilmphWKJfaVQFu7pQ     5.0
#
# [28612 rows x 3 columns]

# %%
trainset
# Out:
#                         userID                  itemID  rating
# 0       n6-Gk65cPZL6Uz8qRm3NYw  WTqjgwHlXbSFevF32_DJVw     5.0
# 1       bLPmbJ0x70HSHfD-2n_smw  WTqjgwHlXbSFevF32_DJVw     1.0
# 2       n6-Gk65cPZL6Uz8qRm3NYw  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 3       wJgtf18VKKZq9A6ZQUybQw  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 4       jqyS91iI63nyztPAvRk1AQ  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 5       ktm2YMsb65tRnePcYpVlqg  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 6       CHUMBPZdstb0OMc26jlldg  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 7       CHUMBPZdstb0OMc26jlldg  30Q5xBagQHmkwp8Q9I1FCg     3.0
# 8       iOR5mdeMaR36VbA76IGbMQ  30Q5xBagQHmkwp8Q9I1FCg     2.0
# 9       X7NHc1i4LgqCPiltnuvR1g  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 10      oXDS2gQ-2kbjOTEHQ5nb1Q  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 11      s7W-PFXAhqBxTw0wqJ1JEA  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 12      JHa6QhwsnQ3tBfoHwz9pJg  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 13      sNlbpvPA5Mg7MMZXphRJAA  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 14      t7gM9zerhBzufAsrgx8GzA  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 15      yGQ79bkbIUlkF6xKCaAf3A  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 16      IyeMSj7mju67Q7zs4QSxTg  30Q5xBagQHmkwp8Q9I1FCg     3.0
# 17      RPg7vzYRsAJy-GBp8CrSsA  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 18      ytlj-nxVL8pX5gCEdUhVjw  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 19      n6-Gk65cPZL6Uz8qRm3NYw  UtWngqS-WloIY_A53W5K-Q     5.0
# 20      l-B4axUNxQ9FVVxeQm8t2A  UtWngqS-WloIY_A53W5K-Q     2.0
# 21      mjhC0hdu1mt4SMbdQBqCHA  UtWngqS-WloIY_A53W5K-Q     5.0
# 22      rkmTGP3FR3_uUb-urnD9qA  UtWngqS-WloIY_A53W5K-Q     4.0
# 23      XM3xtNqthJj2736FDD-gSw  UtWngqS-WloIY_A53W5K-Q     1.0
# 24      qW12oOxahfbm6cbrCv72Iw  UtWngqS-WloIY_A53W5K-Q     1.0
# 25      RtrYx7l2vPJ-8tk5M_a4Ng  UtWngqS-WloIY_A53W5K-Q     5.0
# 26      PECPA5Aj1zEQ30ejMG31Iw  UtWngqS-WloIY_A53W5K-Q     1.0
# 27      1URgpcG2uv0kH2oP_RSGbA  UtWngqS-WloIY_A53W5K-Q     5.0
# 28      m9PQbQBnc3KyusOMrmE7xw  UtWngqS-WloIY_A53W5K-Q     4.0
# 29      PiUh_zFkm91FXGxjKaGzNA  UtWngqS-WloIY_A53W5K-Q     1.0
# ...                        ...                     ...     ...
# 406012  bd-fJCIqjGHf_0Sr3cpeIw  LivM8th5aKOCym2rBOypaQ     5.0
# 406013  bd-fJCIqjGHf_0Sr3cpeIw  zcRffpb9mP25Law5ccbsKQ     1.0
# 406014  DIN8hew5VSuVBvzu2E2HxQ  Fd5Q8GrB-jlAIPM8AmL07w     5.0
# 406015  UzeNGTY0P-7BSl10seC41Q  v2GJWvZqEAjUc22hZUYzYw     2.0
# 406016  u18VHGQINV4g0EEBun3VdQ  _ULxHE2fF-9C4cCRBdFbiw     1.0
# 406017  BtJ_JaUGhEVMkhKk3OgPeA  MvVCSyFIpmKKV8URk0HWIQ     1.0
# 406018  HjXyQ3AkIBi0l6AkPFL8eQ  HcEJ2YiSLX_mT3RE0hvKWQ     1.0
# 406019  SsxFxIn4CQXlvsg1L5JYzA  k9nfd3oUEGjd8G1FMfLbMQ     1.0
# 406020  SsxFxIn4CQXlvsg1L5JYzA  k9nfd3oUEGjd8G1FMfLbMQ     1.0
# 406021  ZSa87jzrbvNx2iKLXxDcgA  RvrR0l5QGUK5qxcHZUSrFA     1.0
# 406022  ZSa87jzrbvNx2iKLXxDcgA  AE3Qz_POf13piq2Z-RA5Kg     1.0
# 406023  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406024  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406025  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406026  j9hSpmKjnIhSQpn8Cgx6WQ  w4rh3YzQ4DkOIE9MNs8_jA     5.0
# 406027  Yg5WB_IxkUDXGG3__KBmIw  BOMFEp6rhfREWwia0AhVdg     5.0
# 406028  vcjgxb2wrY77KY_LUIBGPQ  499ugPqwBhr-EQYnCuFC0A     5.0
# 406029  vcjgxb2wrY77KY_LUIBGPQ  499ugPqwBhr-EQYnCuFC0A     5.0
# 406030  vcjgxb2wrY77KY_LUIBGPQ  y3yzAYE9pFyYtGgyKsyuLw     1.0
# 406031  rBGStJwT8F31ZKfxR-3LDg  KHMowVxKO348SVGzfMh88A     5.0
# 406032  A6QhMRq4IoSi8jwztMaPZw  44diypduswYIqxBSrNr0lA     1.0
# 406033  ZIGAOAheQcxegpQiQLlvKA  ru7uYlgpg7vwRDFVQlpNaw     4.0
# 406034  Al1sBOu0clEMRmIrURVKYQ  -LdlgJrCqdgmf2Zq005cIg     5.0
# 406035  Al1sBOu0clEMRmIrURVKYQ  qY4uRygFDKieLa8n4C6WJg     5.0
# 406036  3pkmfj8YNe4I-WMAjPWX6w  ny79ZOnR9yLTN85Vg2BJVg     1.0
# 406037  HTHkos0ZMecUwNVChYtLfQ  tsHIGsL9LsXDEjHGhpIbLg     5.0
# 406038  fj4Civ5Ec2KD3TcbxX2iTQ  Lh6EHPV59bE_j1Hi65OXNw     5.0
# 406039  M1lN8ENVHvFexfYA-0-f5g  1lWgMvsY8QvrFlnXong-pg     5.0
# 406040  M1lN8ENVHvFexfYA-0-f5g  FUcreFa1JIkNCbJH8zYRbw     1.0
# 406041  M1lN8ENVHvFexfYA-0-f5g  FUcreFa1JIkNCbJH8zYRbw     1.0
#
# [406042 rows x 3 columns]

# %%
trainset[['userID','itemID','rating']]
# Out:
#                         userID                  itemID  rating
# 0       n6-Gk65cPZL6Uz8qRm3NYw  WTqjgwHlXbSFevF32_DJVw     5.0
# 1       bLPmbJ0x70HSHfD-2n_smw  WTqjgwHlXbSFevF32_DJVw     1.0
# 2       n6-Gk65cPZL6Uz8qRm3NYw  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 3       wJgtf18VKKZq9A6ZQUybQw  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 4       jqyS91iI63nyztPAvRk1AQ  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 5       ktm2YMsb65tRnePcYpVlqg  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 6       CHUMBPZdstb0OMc26jlldg  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 7       CHUMBPZdstb0OMc26jlldg  30Q5xBagQHmkwp8Q9I1FCg     3.0
# 8       iOR5mdeMaR36VbA76IGbMQ  30Q5xBagQHmkwp8Q9I1FCg     2.0
# 9       X7NHc1i4LgqCPiltnuvR1g  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 10      oXDS2gQ-2kbjOTEHQ5nb1Q  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 11      s7W-PFXAhqBxTw0wqJ1JEA  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 12      JHa6QhwsnQ3tBfoHwz9pJg  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 13      sNlbpvPA5Mg7MMZXphRJAA  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 14      t7gM9zerhBzufAsrgx8GzA  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 15      yGQ79bkbIUlkF6xKCaAf3A  30Q5xBagQHmkwp8Q9I1FCg     1.0
# 16      IyeMSj7mju67Q7zs4QSxTg  30Q5xBagQHmkwp8Q9I1FCg     3.0
# 17      RPg7vzYRsAJy-GBp8CrSsA  30Q5xBagQHmkwp8Q9I1FCg     5.0
# 18      ytlj-nxVL8pX5gCEdUhVjw  30Q5xBagQHmkwp8Q9I1FCg     4.0
# 19      n6-Gk65cPZL6Uz8qRm3NYw  UtWngqS-WloIY_A53W5K-Q     5.0
# 20      l-B4axUNxQ9FVVxeQm8t2A  UtWngqS-WloIY_A53W5K-Q     2.0
# 21      mjhC0hdu1mt4SMbdQBqCHA  UtWngqS-WloIY_A53W5K-Q     5.0
# 22      rkmTGP3FR3_uUb-urnD9qA  UtWngqS-WloIY_A53W5K-Q     4.0
# 23      XM3xtNqthJj2736FDD-gSw  UtWngqS-WloIY_A53W5K-Q     1.0
# 24      qW12oOxahfbm6cbrCv72Iw  UtWngqS-WloIY_A53W5K-Q     1.0
# 25      RtrYx7l2vPJ-8tk5M_a4Ng  UtWngqS-WloIY_A53W5K-Q     5.0
# 26      PECPA5Aj1zEQ30ejMG31Iw  UtWngqS-WloIY_A53W5K-Q     1.0
# 27      1URgpcG2uv0kH2oP_RSGbA  UtWngqS-WloIY_A53W5K-Q     5.0
# 28      m9PQbQBnc3KyusOMrmE7xw  UtWngqS-WloIY_A53W5K-Q     4.0
# 29      PiUh_zFkm91FXGxjKaGzNA  UtWngqS-WloIY_A53W5K-Q     1.0
# ...                        ...                     ...     ...
# 406012  bd-fJCIqjGHf_0Sr3cpeIw  LivM8th5aKOCym2rBOypaQ     5.0
# 406013  bd-fJCIqjGHf_0Sr3cpeIw  zcRffpb9mP25Law5ccbsKQ     1.0
# 406014  DIN8hew5VSuVBvzu2E2HxQ  Fd5Q8GrB-jlAIPM8AmL07w     5.0
# 406015  UzeNGTY0P-7BSl10seC41Q  v2GJWvZqEAjUc22hZUYzYw     2.0
# 406016  u18VHGQINV4g0EEBun3VdQ  _ULxHE2fF-9C4cCRBdFbiw     1.0
# 406017  BtJ_JaUGhEVMkhKk3OgPeA  MvVCSyFIpmKKV8URk0HWIQ     1.0
# 406018  HjXyQ3AkIBi0l6AkPFL8eQ  HcEJ2YiSLX_mT3RE0hvKWQ     1.0
# 406019  SsxFxIn4CQXlvsg1L5JYzA  k9nfd3oUEGjd8G1FMfLbMQ     1.0
# 406020  SsxFxIn4CQXlvsg1L5JYzA  k9nfd3oUEGjd8G1FMfLbMQ     1.0
# 406021  ZSa87jzrbvNx2iKLXxDcgA  RvrR0l5QGUK5qxcHZUSrFA     1.0
# 406022  ZSa87jzrbvNx2iKLXxDcgA  AE3Qz_POf13piq2Z-RA5Kg     1.0
# 406023  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406024  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406025  Cbh3HsgbqgWk1IEdNWX8Mg  8qTFkDXUJDHrVI9XmxMuEA     5.0
# 406026  j9hSpmKjnIhSQpn8Cgx6WQ  w4rh3YzQ4DkOIE9MNs8_jA     5.0
# 406027  Yg5WB_IxkUDXGG3__KBmIw  BOMFEp6rhfREWwia0AhVdg     5.0
# 406028  vcjgxb2wrY77KY_LUIBGPQ  499ugPqwBhr-EQYnCuFC0A     5.0
# 406029  vcjgxb2wrY77KY_LUIBGPQ  499ugPqwBhr-EQYnCuFC0A     5.0
# 406030  vcjgxb2wrY77KY_LUIBGPQ  y3yzAYE9pFyYtGgyKsyuLw     1.0
# 406031  rBGStJwT8F31ZKfxR-3LDg  KHMowVxKO348SVGzfMh88A     5.0
# 406032  A6QhMRq4IoSi8jwztMaPZw  44diypduswYIqxBSrNr0lA     1.0
# 406033  ZIGAOAheQcxegpQiQLlvKA  ru7uYlgpg7vwRDFVQlpNaw     4.0
# 406034  Al1sBOu0clEMRmIrURVKYQ  -LdlgJrCqdgmf2Zq005cIg     5.0
# 406035  Al1sBOu0clEMRmIrURVKYQ  qY4uRygFDKieLa8n4C6WJg     5.0
# 406036  3pkmfj8YNe4I-WMAjPWX6w  ny79ZOnR9yLTN85Vg2BJVg     1.0
# 406037  HTHkos0ZMecUwNVChYtLfQ  tsHIGsL9LsXDEjHGhpIbLg     5.0
# 406038  fj4Civ5Ec2KD3TcbxX2iTQ  Lh6EHPV59bE_j1Hi65OXNw     5.0
# 406039  M1lN8ENVHvFexfYA-0-f5g  1lWgMvsY8QvrFlnXong-pg     5.0
# 406040  M1lN8ENVHvFexfYA-0-f5g  FUcreFa1JIkNCbJH8zYRbw     1.0
# 406041  M1lN8ENVHvFexfYA-0-f5g  FUcreFa1JIkNCbJH8zYRbw     1.0
#
# [406042 rows x 3 columns]

# %%
# transform to work with surprise
reader = Reader(rating_scale = (0.0, 5.0))
train_data = Dataset.load_from_df(trainset[['userID','itemID','rating']], reader)
test_data = Dataset.load_from_df(testset[['userID','itemID','rating']], reader)

# %%
train_sr = train_data.build_full_trainset()

# %%
test_sr_before = test_data.build_full_trainset()

# %%
test_sr = test_sr_before.build_testset()

# %%
algo.fit(train_sr)
predictions = algo.test(test_sr)
accuracy.rmse(predictions)
# Out:
# RMSE: 1.3877
# 1.3877083808706543
